# %% [markdown]
# # Julia is fast
#
# Very often, benchmarks are used to compare languages.  These benchmarks can lead to long discussions, first as to exactly what is being benchmarked and secondly what explains the differences.  These simple questions can sometimes get more complicated than you at first might imagine.
#
# The purpose of this notebook is for you to see a simple benchmark for yourself.  One can read the notebook and see what happened on the author's Macbook Pro with a 4-core Intel Core I7, or run the notebook yourself.
#
# (This material began life as a wonderful lecture by Steven Johnson at MIT: https://github.com/stevengj/18S096-iap17/blob/master/lecture1/Boxes-and-registers.ipynb.)

# %% [markdown]
# # `sum`: An easy enough function to understand

# %% [markdown]
# Consider the  **sum** function `sum(a)`, which computes
#
# $$
# \mathrm{sum}(a) = \sum_{i=1}^n a_i.
# $$

# %%
a = rand(10^7) # array of random numbers, uniform on [0,1)
# Out:
# 10000000-element Array{Float64,1}:
#  0.754033
#  0.0762138
#  0.550958
#  0.829073
#  0.435304
#  0.254182
#  0.844903
#  0.828836
#  0.158743
#  0.35219
#  0.059766
#  0.29107
#  0.106671
#  ⋮
#  0.772866
#  0.278005
#  0.329753
#  0.399957
#  0.520319
#  0.226333
#  0.0397717
#  0.383874
#  0.590705
#  0.483153
#  0.552134
#  0.948234

# %%
sum(a) # one expects this is 10^7 * .5 , since the mean of each entry is .5
# Out:
# 5.000149232001643e6

# %% [markdown]
# # Benchmarking a few ways in a few languages

# %%
#Pkg.add("BenchmarkTools")

# %%
using BenchmarkTools  # Julia package for benchmarking

# %% [markdown]
# #  1. The C language:
#
# C is often considered the gold standard: difficult on the human, nice for the machine. Getting within a factor of 2 of C is often satisfying. Nonetheless, even within C, there are many kinds of optimizations possible that a naive C writer may or may not get the advantage of.
#
# The current author does not speak C, so he does not read the cell below, but is happy to know that you can put C code in a Julia session, compile it, and run it.

# %%
C_code = """
#include <stddef.h>
double c_sum(size_t n, double *X) {
    double s = 0.0;
    for (size_t i = 0; i < n; ++i) {
        s += X[i];
    }
    return s;
}
"""

const Clib = tempname()   # make a temporary file


# compile to a shared library by piping C_code to gcc
# (works only if you have gcc installed):

open(`gcc -fPIC -O3 -msse3 -xc -shared -o $(Clib * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# define a Julia function that calls the C function:
c_sum(X::Array{Float64}) = ccall(("c_sum", Clib), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# WARNING: redefining constant Clib
# WARNING: Method definition c_sum(Array{Float64, N<:Any}) in module Main at In[65]:23 overwritten at In[125]:23.
# c_sum (generic function with 1 method)

# %%
c_sum(a)
# Out:
# 5.000149232001563e6

# %%
c_sum(a) ≈ sum(a) # type \approx and then <TAB> to get the ≈ symbol
# Out:
# true

# %%
?isapprox
# Out:
# search: isapprox
# ```
# isapprox(x, y; rtol::Real=sqrt(eps), atol::Real=0)
# ```
#
# Inexact equality comparison: `true` if `norm(x-y) <= atol + rtol*max(norm(x), norm(y))`. The default `atol` is zero and the default `rtol` depends on the types of `x` and `y`.
#
# For real or complex floating-point values, `rtol` defaults to `sqrt(eps(typeof(real(x-y))))`. This corresponds to requiring equality of about half of the significand digits. For other types, `rtol` defaults to zero.
#
# `x` and `y` may also be arrays of numbers, in which case `norm` defaults to `vecnorm` but may be changed by passing a `norm::Function` keyword argument. (For numbers, `norm` is the same thing as `abs`.) When `x` and `y` are arrays, if `norm(x-y)` is not finite (i.e. `±Inf` or `NaN`), the comparison falls back to checking whether all elements of `x` and `y` are approximately equal component-wise.
#
# The binary operator `≈` is equivalent to `isapprox` with the default arguments, and `x ≉ y` is equivalent to `!isapprox(x,y)`.
#
# ```
# isapprox(x::FixedPoint, y::FixedPoint; rtol=0, atol=max(eps(x), eps(y)))
# ```
#
# For FixedPoint numbers, the default criterion is that `x` and `y` differ by no more than `eps`, the separation between adjacent fixed-point numbers.

# %% [markdown]
# We can now benchmark the C code directly from Julia:

# %%
c_bench = @benchmark c_sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     8.137 ms (0.00% GC)
#   median time:      8.308 ms (0.00% GC)
#   mean time:        8.674 ms (0.00% GC)
#   maximum time:     12.578 ms (0.00% GC)
#   --------------
#   samples:          575
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%

# %%
println("C: Fastest time was $(minimum(c_bench.times)/1e6) msecs.")
# Out:
# C: Fastest time was 8.137128 msecs.

# %%
d=Dict()
d["c"] = minimum(c_bench.times)/1e6
d
# Out:
# Dict{Any,Any} with 1 entry:
#   "c" => 8.13713

# %%
using Plots
gr()
# Out:
# Plots.GRBackend()

# %%
t = c_bench.times/1e6 # time in milliseconds
m,σ = minimum(t), std(t)

histogram(t,bins=500,
    xlim=(m-.01,m+σ),
    xlabel="milliseconds",ylabel="count",label="")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 36.9926,369.674 596.063,369.674 596.063,3.93701 36.9926,3.93701
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="36" y="3" width="560" height="366"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   116.957,364.188 116.957,9.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   279.657,364.188 279.657,9.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   442.356,364.188 442.356,9.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,369.674 587.677,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,263.663 587.677,263.663
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,157.653 587.677,157.653
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.3786,51.6418 587.677,51.6418
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,369.674 596.063,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   116.957,369.674 116.957,364.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   279.657,369.674 279.657,364.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   442.356,369.674 442.356,364.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,369.674 36.9926,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,369.674 45.3786,369.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,263.663 45.3786,263.663
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,157.653 45.3786,157.653
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   36.9926,51.6418 45.3786,51.6418
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 116.957, 381.674)" x="116.957" y="381.674">8.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 279.657, 381.674)" x="279.657" y="381.674">8.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 442.356, 381.674)" x="442.356" y="381.674">8.75</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 374.174)" x="35.7926" y="374.174">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 268.163)" x="35.7926" y="268.163">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 162.153)" x="35.7926" y="162.153">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 35.7926, 56.1418)" x="35.7926" y="56.1418">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 316.528, 397.6)" x="316.528" y="397.6">milliseconds</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 186.806)" x="14.4" y="186.806">count</text>
# </g>
# <polygon clip-path="url(#clip02)" points="
# 43.5005,3.93701 43.5005,369.674 49.2808,369.674 49.2808,3.93701 43.5005,3.93701 43.5005,3.93701
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   43.5005,3.93701 43.5005,369.674 49.2808,369.674 49.2808,3.93701 43.5005,3.93701
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 49.2808,258.363 49.2808,369.674 55.061,369.674 55.061,258.363 49.2808,258.363 49.2808,258.363
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   49.2808,258.363 49.2808,369.674 55.061,369.674 55.061,258.363 49.2808,258.363
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 55.061,359.073 55.061,369.674 60.8412,369.674 60.8412,359.073 55.061,359.073 55.061,359.073
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   55.061,359.073 55.061,369.674 60.8412,369.674 60.8412,359.073 55.061,359.073
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 60.8412,364.374 60.8412,369.674 66.6214,369.674 66.6214,364.374 60.8412,364.374 60.8412,364.374
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   60.8412,364.374 60.8412,369.674 66.6214,369.674 66.6214,364.374 60.8412,364.374
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 66.6214,343.171 66.6214,369.674 72.4016,369.674 72.4016,343.171 66.6214,343.171 66.6214,343.171
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   66.6214,343.171 66.6214,369.674 72.4016,369.674 72.4016,343.171 66.6214,343.171
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 72.4016,343.171 72.4016,369.674 78.1819,369.674 78.1819,343.171 72.4016,343.171 72.4016,343.171
#   " fill="#0099ff" fill-opacity="1"/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   72.4016,343.171 72.4016,369.674 78.1819,369.674 78.1819,343.171 72.4016,343.171
#   "/>
# <polygon clip-path="url(#clip02)" points="
# 78.1819,316.669 78.1819,369.674 83.9621,369.674 83.9621,316.669 78.1819,316.669 78.1819,316.669
#   " fill="#0099ff" fil

# %% [markdown]
# # 2. Python's built in `sum`

# %%
# Julia interface to Python:
# Pkg.add("PyCall")

# %%
using PyCall

# %%
# call a low-level PyCall function to get a Python list, because
# by default PyCall will convert to a NumPy array instead (we benchmark NumPy below):

apy_list = PyCall.array2py(a, 1, 1)

# get the Python built-in "sum" function:
pysum = pybuiltin("sum")
# Out:
# PyObject <built-in function sum>

# %%
pysum(a)
# Out:
# 5.000217101416825e6

# %%
pysum(a) ≈ sum(a)
# Out:
# true

# %%
py_list_bench = @benchmark $pysum($apy_list)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  672 bytes
#   allocs estimate:  19
#   --------------
#   minimum time:     68.576 ms (0.00% GC)
#   median time:      71.747 ms (0.00% GC)
#   mean time:        74.828 ms (0.00% GC)
#   maximum time:     96.319 ms (0.00% GC)
#   --------------
#   samples:          67
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%

# %%
d["Python builtin"]=minimum(py_list_bench.times)/1e6
d
# Out:
# Dict{Any,Any} with 2 entries:
#   "c"              => 8.13713
#   "Python builtin" => 68.5762

# %% [markdown]
# # 3. Python: `numpy`
#
# ## Takes advantage of hardware "SIMD", but only works when it works.
#
# `numpy` is an optimized C library, callable from Python

# %% [markdown]
# If it is not installed, install it from Julia as follows:

# %%
# using Conda 
# Conda.add("numpy")

# %%
numpy_sum = pyimport("numpy")["sum"]
apy_numpy = PyObject(a) # converts to a numpy array by default

py_numpy_bench = @benchmark $numpy_sum($apy_numpy)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  960 bytes
#   allocs estimate:  25
#   --------------
#   minimum time:     3.925 ms (0.00% GC)
#   median time:      4.292 ms (0.00% GC)
#   mean time:        4.416 ms (0.00% GC)
#   maximum time:     8.754 ms (0.00% GC)
#   --------------
#   samples:          1126
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%

# %%
numpy_sum(apy_list) # python thing
# Out:
# 5.000217101416651e6

# %%
numpy_sum(apy_list) ≈ sum(a)
# Out:
# true

# %%
d["Python numpy"]=minimum(py_numpy_bench.times)/1e6
d
# Out:
# Dict{Any,Any} with 3 entries:
#   "c"              => 8.13713
#   "Python builtin" => 68.5762
#   "Python numpy"   => 3.92471

# %% [markdown]
# # 4. Python, hand written

# %%
# It currently takes a little bit of hackery to define a custom Python function
# in a Julia string and call it via PyCall, sorry:

syms = PyDict{AbstractString, PyObject}()
syms["syms"] = PyObject(Any[])

pyeval("""
def mysum(a):
    s = 0.0
    for x in a:
        s = s + x
    return s

syms.insert(0, mysum)
""", PyAny, syms, PyCall.Py_file_input)

mysum_py = syms["syms"][1] # a reference to the Python mysum function
# Out:
# PyObject <function mysum at 0x3208ad5f0>

# %%
pyhand = @benchmark $mysum_py($apy_list)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  672 bytes
#   allocs estimate:  19
#   --------------
#   minimum time:     447.447 ms (0.00% GC)
#   median time:      481.731 ms (0.00% GC)
#   mean time:        473.573 ms (0.00% GC)
#   maximum time:     499.767 ms (0.00% GC)
#   --------------
#   samples:          11
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%

# %%
mysum_py(apy_list)
# Out:
# 5.000217101416825e6

# %%
mysum_py(apy_list) ≈ sum(a)
# Out:
# true

# %%
d["Python hand"]=minimum(pyhand.times)/1e6
d
# Out:
# Dict{Any,Any} with 4 entries:
#   "c"              => 8.13713
#   "Python builtin" => 68.5762
#   "Python numpy"   => 3.92471
#   "Python hand"    => 447.447

# %% [markdown]
# # 5. Julia (built-in)
#
# ## Written directly in Julia, not in C!

# %%
@which sum(a)
# Out:
# sum(a) at reduce.jl:229

# %%
j_bench = @benchmark sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     3.748 ms (0.00% GC)
#   median time:      4.024 ms (0.00% GC)
#   mean time:        4.217 ms (0.00% GC)
#   maximum time:     7.924 ms (0.00% GC)
#   --------------
#   samples:          1179
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%

# %%
d["Julia built in"]=minimum(j_bench.times)/1e6
d
# Out:
# Dict{Any,Any} with 5 entries:
#   "c"              => 8.13713
#   "Python builtin" => 68.5762
#   "Python numpy"   => 3.92471
#   "Python hand"    => 447.447
#   "Julia built in" => 3.7481

# %% [markdown]
# # 6. Julia (hand-written)

# %%
function mysum(A)   
    s = 0.0  # s = zero(eltype(A))
    for a in A
        s += a
    end
    s
end
# Out:
# WARNING: Method definition mysum(Any) in module Main at In[94]:2 overwritten at In[101]:2.
# mysum (generic function with 1 method)

# %%
j_bench_hand = @benchmark mysum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     8.141 ms (0.00% GC)
#   median time:      8.566 ms (0.00% GC)
#   mean time:        8.540 ms (0.00% GC)
#   maximum time:     13.113 ms (0.00% GC)
#   --------------
#   samples:          585
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%

# %%
d["Julia hand"]=minimum(j_bench_hand.times)/1e6
d
# Out:
# Dict{Any,Any} with 6 entries:
#   "c"              => 8.13713
#   "Python builtin" => 68.5762
#   "Python numpy"   => 3.92471
#   "Python hand"    => 447.447
#   "Julia hand"     => 8.14124
#   "Julia built in" => 3.7481

# %%
h(x,y) = x*y
# Out:
# WARNING: Method definition h(Any, Any) in module Main at In[103]:1 overwritten at In[108]:1.
# h (generic function with 1 method)

# %%
@code_native h(5,6)
# Out:
# 	.section	__TEXT,__text,regular,pure_instructions
# Filename: In[108]
# 	pushq	%rbp
# 	movq	%rsp, %rbp
# Source line: 1
# 	imulq	%rsi, %rdi
# 	movq	%rdi, %rax
# 	popq	%rbp
# 	retq
# 	nopl	(%rax)

# %%
2 * 3
# Out:
# 6

# %%
2.0 * 3.0
# Out:
# 6.0

# %% [markdown]
# ## Julia Parallel

# %%
#Pkg.add("DistributedArrays")

# %%
addprocs(4)
# Out:
# 4-element Array{Int64,1}:
#  2
#  3
#  4
#  5

# %%
@everywhere using DistributedArrays

# %%
â = distribute(a)
# Out:
# 4-element Array{Int64,1}:
#  2
#  3
#  4
#  5

# %%
#â.indexes
â.pids
# Out:
# 4-element Array{Int64,1}:
#  2
#  3
#  4
#  5

# %%
j_par = @benchmark  sum($â)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  43.64 KiB
#   allocs estimate:  553
#   --------------
#   minimum time:     2.100 ms (0.00% GC)
#   median time:      2.192 ms (0.00% GC)
#   mean time:        2.273 ms (0.30% GC)
#   maximum time:     5.943 ms (58.86% GC)
#   --------------
#   samples:          2177
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%

# %%
d["Julia par"]=minimum(j_par.times)/1e6
d
# Out:
# Dict{Any,Any} with 7 entries:
#   "c"              => 8.13713
#   "Python builtin" => 68.5762
#   "Python numpy"   => 3.92471
#   "Julia par"      => 2.1001
#   "Python hand"    => 447.447
#   "Julia hand"     => 8.14124
#   "Julia built in" => 3.7481

# %%
b̂ = drand(10^8)
# Out:
# 100000000-element DistributedArrays.DArray{Float64,1,Array{Float64,1}}:
#  0.287512
#  0.207542
#  0.138869
#  0.928497
#  0.504395
#  0.302976
#  0.365259
#  0.895781
#  0.446415
#  0.704144
#  0.12339
#  0.950467
#  0.824553
#  ⋮
#  0.0888048
#  0.0486551
#  0.881771
#  0.688016
#  0.350397
#  0.086147
#  0.938969
#  0.172885
#  0.42417
#  0.489405
#  0.907067
#  0.0486962

# %%
j_par_b = @benchmark  sum($b̂)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  43.64 KiB
#   allocs estimate:  553
#   --------------
#   minimum time:     37.513 ms (0.00% GC)
#   median time:      37.925 ms (0.00% GC)
#   mean time:        38.081 ms (0.00% GC)
#   maximum time:     41.964 ms (0.00% GC)
#   --------------
#   samples:          132
#   evals/sample:     1
#   time tolerance:   5.00%
#   memory tolerance: 1.00%
